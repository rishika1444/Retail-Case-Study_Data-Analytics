# %%
import pandas as pd
import numpy as np
import pandas_profiling as pp
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime,timedelta

# %%
Customers = pd.read_csv('Customer.csv')

# %%
Customers.head()
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
Transactions = pd.read_csv('Transactions.csv')

# %%
Transactions.head()
# Out:
#    transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  Qty  \
# 0     80712190438   270351  28-02-2014                 1              1   -5
# 1     29258453508   270384  27-02-2014                 5              3   -5
# 2     51750724947   273420  24-02-2014                 6              5   -2
# 3     93274880719   271509  24-02-2014                11              6   -3
# 4     51750724947   273420  23-02-2014                 6              5   -2
#
#    Rate      Tax  total_amt Store_type
# 0  -772  405.300  -4265.300     e-Shop
# 1 -1497  785.925  -8270.925     e-Shop
# 2  -791  166.110  -1748.110   TeleShop
# 3 -1363  429.345  -4518.345     e-Shop
# 4  -791  166.110  -1748.110   TeleShop

# %%
Product_Hierarchy = pd.read_csv('prod_cat_info.csv')

# %%
Product_Hierarchy.head()
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens
# 1              1  Clothing                  1       Women
# 2              1  Clothing                  3        Kids
# 3              2  Footwear                  1        Mens
# 4              2  Footwear                  3       Women

# %% [markdown]
# ### 1. Merge the datasets Customers, Product Hierarchy and Transactions as Customer_Final. Ensure to keep all customers who have done transactions with us and select the join type accordingly.

# %%
Customer_Final = pd.merge(left=pd.merge(left=Customers,right=Transactions,how='left',left_on='customer_Id',right_on='cust_id'),right=Product_Hierarchy,how='inner',left_on=['prod_cat_code','prod_subcat_code'],right_on=['prod_cat_code','prod_sub_cat_code'])

# %%
Customer_Final.head()
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1       275152  16-01-1970      M        4.0    7.310943e+10  275152.0
# 2       275034  18-01-1970      F        4.0    6.477727e+10  275034.0
# 3       270829  22-01-1970      F        8.0    8.717434e+10  270829.0
# 4       267657  29-01-1970      F        7.0    7.624274e+10  267657.0
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty    Rate      Tax  \
# 0  13-01-2014               7.0            5.0  5.0   187.0   98.175
# 1  25-03-2011               7.0            5.0  2.0   464.0   97.440
# 2  23-05-2011               7.0            5.0  2.0   197.0   41.370
# 3   9/12/2013               7.0            5.0  4.0  1141.0  479.220
# 4  23-05-2013               7.0            5.0  4.0  1020.0  428.400
#
#    total_amt      Store_type prod_cat  prod_sub_cat_code prod_subcat
# 0   1033.175        TeleShop    Books                  7     Fiction
# 1   1025.440          e-Shop    Books                  7     Fiction
# 2    435.370  Flagship store    Books                  7     Fiction
# 3   5043.220          e-Shop    Books                  7     Fiction
# 4   4508.400          e-Shop    Books                  7     Fiction

# %%
Customer_Final.shape
# Out:
# (23053, 17)

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23053 entries, 0 to 23052
# Data columns (total 17 columns):
# customer_Id          23053 non-null int64
# DOB                  23053 non-null object
# Gender               23044 non-null object
# city_code            23045 non-null float64
# transaction_id       23053 non-null float64
# cust_id              23053 non-null float64
# tran_date            23053 non-null object
# prod_subcat_code     23053 non-null float64
# prod_cat_code        23053 non-null float64
# Qty                  23053 non-null float64
# Rate                 23053 non-null float64
# Tax                  23053 non-null float64
# total_amt            23053 non-null float64
# Store_type           23053 non-null object
# prod_cat             23053 non-null object
# prod_sub_cat_code    23053 non-null int64
# prod_subcat          23053 non-null object
# dtypes: float64(9), int64(2), object(6)
# memory usage: 3.2+ MB

# %% [markdown]
# ### 2. Prepare a summary report for the merged data set.

# %%
pp.ProfileReport(Customer_Final)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>17 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>23053 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>3.2 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>144.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>9 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>6 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_DOB"><code>DOB</code></a> has a high cardinality: 3987 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_cust_id"><code>cust_id</code></a> is highly correlated with <a href="#pp_var_customer_Id"><code>customer_Id</code></a> (ρ = 1) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_prod_sub_cat_code"><code>prod_sub_cat_code</code></a> is highly correlated with <a href="#pp_var_prod_subcat_code"><code>prod_subcat_code</code></a> (ρ = 1) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_tran_date"><code>tran_date</code></a> has a high cardinality: 1129 distinct values  <span class="label label-warning">Warning</span></li><li>Dataset has 13 duplicate rows <span class="label label-warning">Warning</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_DOB">DOB<br/>
#             <small>Categorical</small>
#         </p>
#     </div><div class="col-md-3">
#     <table class="stats ">
#         <tr class="alert">
#             <th>Distinct count</th>

# %%
Customer_Final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1       275152  16-01-1970      M        4.0    7.310943e+10  275152.0
# 2       275034  18-01-1970      F        4.0    6.477727e+10  275034.0
# 3       270829  22-01-1970      F        8.0    8.717434e+10  270829.0
# 4       267657  29-01-1970      F        7.0    7.624274e+10  267657.0
# 5       274630  01-02-1970      M        4.0    7.835735e+10  274630.0
# 6       273541  01-02-1970      M        4.0    2.391682e+10  273541.0
# 7       269008  13-02-1970      F        6.0    3.556057e+10  269008.0
# 8       269008  13-02-1970      F        6.0    9.403331e+10  269008.0
# 9       267199  14-02-1970    NaN        2.0    5.674926e+10  267199.0
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty    Rate      Tax  \
# 0  13-01-2014               7.0            5.0  5.0   187.0   98.175
# 1  25-03-2011               7.0            5.0  2.0   464.0   97.440
# 2  23-05-2011               7.0            5.0  2.0   197.0   41.370
# 3   9/12/2013               7.0            5.0  4.0  1141.0  479.220
# 4  23-05-2013               7.0            5.0  4.0  1020.0  428.400
# 5   11/4/2012               7.0            5.0  1.0   646.0   67.830
# 6    9/2/2013               7.0            5.0  4.0   410.0  172.200
# 7    9/3/2013               7.0            5.0  1.0  1441.0  151.305
# 8  26-04-2012               7.0            5.0  5.0   746.0  391.650
# 9   11/1/2012               7.0            5.0  4.0  1049.0  440.580
#
#    total_amt      Store_type prod_cat  prod_sub_cat_code prod_subcat
# 0   1033.175        TeleShop    Books                  7     Fiction
# 1   1025.440          e-Shop    Books                  7     Fiction
# 2    435.370  Flagship store    Books                  7     Fiction
# 3   5043.220          e-Shop    Books                  7     Fiction
# 4   4508.400          e-Shop    Books                  7     Fiction
# 5    713.830        TeleShop    Books                  7     Fiction
# 6   1812.200          e-Shop    Books                  7     Fiction
# 7   1592.305          e-Shop    Books                  7     Fiction
# 8   4121.650             MBR    Books                  7     Fiction
# 9   4636.580             MBR    Books                  7     Fiction

# %% [markdown]
# ####  2.a. Get the column names and their corresponding data types

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23053 entries, 0 to 23052
# Data columns (total 17 columns):
# customer_Id          23053 non-null int64
# DOB                  23053 non-null object
# Gender               23044 non-null object
# city_code            23045 non-null float64
# transaction_id       23053 non-null float64
# cust_id              23053 non-null float64
# tran_date            23053 non-null object
# prod_subcat_code     23053 non-null float64
# prod_cat_code        23053 non-null float64
# Qty                  23053 non-null float64
# Rate                 23053 non-null float64
# Tax                  23053 non-null float64
# total_amt            23053 non-null float64
# Store_type           23053 non-null object
# prod_cat             23053 non-null object
# prod_sub_cat_code    23053 non-null int64
# prod_subcat          23053 non-null object
# dtypes: float64(9), int64(2), object(6)
# memory usage: 3.2+ MB

# %% [markdown]
# ####  2. b. Top/Bottom 10 observations

# %%
#Top 10 Observations
Customer_Final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 0       268408  02-01-1970      M        4.0    8.724384e+10  268408.0
# 1       275152  16-01-1970      M        4.0    7.310943e+10  275152.0
# 2       275034  18-01-1970      F        4.0    6.477727e+10  275034.0
# 3       270829  22-01-1970      F        8.0    8.717434e+10  270829.0
# 4       267657  29-01-1970      F        7.0    7.624274e+10  267657.0
# 5       274630  01-02-1970      M        4.0    7.835735e+10  274630.0
# 6       273541  01-02-1970      M        4.0    2.391682e+10  273541.0
# 7       269008  13-02-1970      F        6.0    3.556057e+10  269008.0
# 8       269008  13-02-1970      F        6.0    9.403331e+10  269008.0
# 9       267199  14-02-1970    NaN        2.0    5.674926e+10  267199.0
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty    Rate      Tax  \
# 0  13-01-2014               7.0            5.0  5.0   187.0   98.175
# 1  25-03-2011               7.0            5.0  2.0   464.0   97.440
# 2  23-05-2011               7.0            5.0  2.0   197.0   41.370
# 3   9/12/2013               7.0            5.0  4.0  1141.0  479.220
# 4  23-05-2013               7.0            5.0  4.0  1020.0  428.400
# 5   11/4/2012               7.0            5.0  1.0   646.0   67.830
# 6    9/2/2013               7.0            5.0  4.0   410.0  172.200
# 7    9/3/2013               7.0            5.0  1.0  1441.0  151.305
# 8  26-04-2012               7.0            5.0  5.0   746.0  391.650
# 9   11/1/2012               7.0            5.0  4.0  1049.0  440.580
#
#    total_amt      Store_type prod_cat  prod_sub_cat_code prod_subcat
# 0   1033.175        TeleShop    Books                  7     Fiction
# 1   1025.440          e-Shop    Books                  7     Fiction
# 2    435.370  Flagship store    Books                  7     Fiction
# 3   5043.220          e-Shop    Books                  7     Fiction
# 4   4508.400          e-Shop    Books                  7     Fiction
# 5    713.830        TeleShop    Books                  7     Fiction
# 6   1812.200          e-Shop    Books                  7     Fiction
# 7   1592.305          e-Shop    Books                  7     Fiction
# 8   4121.650             MBR    Books                  7     Fiction
# 9   4636.580             MBR    Books                  7     Fiction

# %%
#Bottom 10 Observations
Customer_Final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id   cust_id  \
# 23043       268914  15-11-1992      F        3.0    1.407824e+09  268914.0
# 23044       269519  17-11-1992      M        9.0    2.971950e+10  269519.0
# 23045       273524  25-11-1992      F        1.0    2.576281e+10  273524.0
# 23046       272141  02-12-1992      F       10.0    7.133709e+10  272141.0
# 23047       272141  02-12-1992      F       10.0    7.133709e+10  272141.0
# 23048       267812  04-12-1992      F        1.0    6.354038e+10  267812.0
# 23049       274618  09-12-1992      F        7.0    7.179320e+10  274618.0
# 23050       268097  15-12-1992      F        7.0    9.121711e+10  268097.0
# 23051       268097  15-12-1992      F        7.0    9.011448e+10  268097.0
# 23052       268097  15-12-1992      F        7.0    9.011448e+10  268097.0
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty    Rate      Tax  \
# 23043   10/6/2011              10.0            5.0  1.0  1252.0  131.460
# 23044  24-12-2013              10.0            5.0  4.0  1036.0  435.120
# 23045  19-11-2012              10.0            5.0  1.0  1401.0  147.105
# 23046  22-07-2012              10.0            5.0 -3.0 -1422.0  447.930
# 23047  16-07-2012              10.0            5.0  3.0  1422.0  447.930
# 23048  10/10/2012              10.0            5.0  3.0   224.0   70.560
# 23049  17-08-2013              10.0            5.0  4.0   691.0  290.220
# 23050    1/2/2012              10.0            5.0  2.0   411.0   86.310
# 23051  31-01-2011              10.0            5.0 -4.0 -1408.0  591.360
# 23052  26-01-2011              10.0            5.0  4.0  1408.0  591.360
#
#        total_amt      Store_type prod_cat  prod_sub_cat_code  prod_subcat
# 23043   1383.460             MBR    Books                 10  Non-Fiction
# 23044   4579.120        TeleShop    Books                 10  Non-Fiction
# 23045   1548.105  Flagship store    Books                 10  Non-Fiction
# 23046  -4713.930          e-Shop    Books                 10  Non-Fiction
# 23047   4713.930          e-Shop    Books                 10  Non-Fiction
# 23048    742.560        TeleShop    Books                 10  Non-Fiction
# 23049   3054.220  Flagship store    Books                 10  Non-Fiction
# 23050    908.310          e-Shop    Books                 10  Non-Fiction
# 23051  -6223.360          e-Shop    Books                 10  Non-Fiction
# 23052   6223.360          e-Shop    Books                 10  Non-Fiction

# %% [markdown]
# #### 2.c.  “Five-number summary” for continuous variables (min, Q1, median, Q3 and max)

# %%
Customer_Final.describe()
# Out:
#          customer_Id     city_code  transaction_id        cust_id  \
# count   23053.000000  23045.000000    2.305300e+04   23053.000000
# mean   271021.746497      5.482534    5.007348e+10  271021.746497
# std      2431.692059      2.863499    2.898194e+10    2431.692059
# min    266783.000000      1.000000    3.268991e+06  266783.000000
# 25%    268935.000000      3.000000    2.493864e+10  268935.000000
# 50%    270980.000000      5.000000    5.009313e+10  270980.000000
# 75%    273114.000000      8.000000    7.533000e+10  273114.000000
# max    275265.000000     10.000000    9.998755e+10  275265.000000
#
#        prod_subcat_code  prod_cat_code           Qty          Rate  \
# count      23053.000000   23053.000000  23053.000000  23053.000000
# mean           6.149091       3.763632      2.432395    636.369713
# std            3.726372       1.677016      2.268406    622.363498
# min            1.000000       1.000000     -5.000000  -1499.000000
# 25%            3.000000       2.000000      1.000000    312.000000
# 50%            5.000000       4.000000      3.000000    710.000000
# 75%           10.000000       5.000000      4.000000   1109.000000
# max           12.000000       6.000000      5.000000   1500.000000
#
#                 Tax     total_amt  prod_sub_cat_code
# count  23053.000000  23053.000000       23053.000000
# mean     248.667192   2107.308002           6.149091
# std      187.177773   2507.561264           3.726372
# min        7.350000  -8270.925000           1.000000
# 25%       98.280000    762.450000           3.000000
# 50%      199.080000   1754.740000           5.000000
# 75%      365.715000   3569.150000          10.000000
# max      787.500000   8287.500000          12.000000

# %% [markdown]
# #### 2.d. Frequency tables for all the categorical variables

# %%
# Convert DOB type to datetime object
Customer_Final.DOB=pd.to_datetime(Customer_Final.DOB,format="%d-%m-%Y")

# %%
# Convert transaction date type to datetime object
def convertDateTime(x):
    x=x.replace('/','-')
    x=pd.to_datetime(x,format='%d-%m-%Y')
    return x

# %%
Customer_Final.tran_date=Customer_Final.tran_date.apply(lambda x: convertDateTime(x))

# %%
def frequency_tables(x):
    plt.figure(figsize=(4,3))
    sns.countplot(x)
    plt.show()

# %%
Customer_Final.select_dtypes(['object']).apply(lambda x: frequency_tables(x))
# Out:
# Gender         None
# Store_type     None
# prod_cat       None
# prod_subcat    None
# dtype: object

# %% [markdown]
# ### 3. Generate histograms for all continuous variables and frequency bars for categorical variables.

# %%
def fn_hist(x):
    plt.figure(figsize=(3, 2))
    x.hist()
    plt.grid(True)
    plt.title('This is a hist for ' + x.name)
    plt.show()

# %%
Customer_Final.select_dtypes(['float64','int64']).apply(fn_hist)
# Out:
# customer_Id          None
# city_code            None
# transaction_id       None
# cust_id              None
# prod_subcat_code     None
# prod_cat_code        None
# Qty                  None
# Rate                 None
# Tax                  None
# total_amt            None
# prod_sub_cat_code    None
# dtype: object

# %%
Customer_Final.select_dtypes(['object']).apply(lambda x: frequency_tables(x))
# Out:
# Gender         None
# Store_type     None
# prod_cat       None
# prod_subcat    None
# dtype: object

# %% [markdown]
# ### 4. Calculate the following information using the merged dataset :

# %% [markdown]
# ####  a. Time period of the available transaction data

# %%
# Time period of the available transaction data
Max_Available_Date=Customer_Final.tran_date.max()

# %%
Max_Available_Date
# Out:
# Timestamp('2014-02-28 00:00:00')

# %%
Min_Available_Date=Customer_Final.tran_date.min()

# %%
Min_Available_Date
# Out:
# Timestamp('2011-01-25 00:00:00')

# %%
(Max_Available_Date - Min_Available_Date).days
# Out:
# 1130

# %% [markdown]
# ####  b. Count of transactions where the total amount of transaction was negative

# %%
# Count of transactions where the total amount of transaction was negative
Customer_Final.loc[(Customer_Final.Qty < 0)].shape
# Out:
# (2177, 17)

# %%
Customer_Final.loc[(Customer_Final.Qty < 0)].count()
# Out:
# customer_Id          2177
# DOB                  2177
# Gender               2176
# city_code            2177
# transaction_id       2177
# cust_id              2177
# tran_date            2177
# prod_subcat_code     2177
# prod_cat_code        2177
# Qty                  2177
# Rate                 2177
# Tax                  2177
# total_amt            2177
# Store_type           2177
# prod_cat             2177
# prod_sub_cat_code    2177
# prod_subcat          2177
# dtype: int64

# %% [markdown]
# ### 5. Analyze which product categories are more popular among females vs male customers.

# %%
# Analyze which product categories are more popular among females vs male customers. 
Customer_Final.Gender.count()
# Out:
# 23044

# %%
gender_cat_count = Customer_Final.groupby(['prod_cat', 'Gender']).agg({'Gender': 'count'})

# %%
product_cat_count = Customer_Final.groupby(['prod_cat']).agg('count')

# %%
product_cat_gender = gender_cat_count.div(product_cat_count, level = "prod_cat") * 100

# %%
product_cat_gender.loc[: , 'Gender']
# Out:
# prod_cat          Gender
# Bags              F         49.749750
#                   M         50.250250
# Books             F         48.623248
#                   M         51.376752
# Clothing          F         48.664187
#                   M         51.335813
# Electronics       F         47.529604
#                   M         52.470396
# Footwear          F         51.000667
#                   M         48.999333
# Home and kitchen  F         48.304264
#                   M         51.695736
# Name: Gender, dtype: float64

# %% [markdown]
# ### 6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
# Which City code has the maximum customers and what was the percentage of customers from that city? 
City_Code_Customers=Customer_Final.groupby('city_code').customer_Id.max().reset_index()

# %%
City_Code_Customers.sort_values('customer_Id',ascending=False).head(1)
# Out:
#    city_code  customer_Id
# 2        3.0       275265

# %%
City_Code_Customers['Customer_Percentage']=(City_Code_Customers.customer_Id/City_Code_Customers.customer_Id.sum())*100

# %%
City_Code_Customers
# Out:
#    city_code  customer_Id  Customer_Percentage
# 0        1.0       275250            10.000127
# 1        2.0       275249            10.000091
# 2        3.0       275265            10.000672
# 3        4.0       275264            10.000636
# 4        5.0       275257            10.000381
# 5        6.0       275252            10.000200
# 6        7.0       275206             9.998529
# 7        8.0       275244             9.999909
# 8        9.0       275216             9.998892
# 9       10.0       275262            10.000563

# %% [raw]
# Hence City Code 3 have max no of customers.

# %% [markdown]
# ### 7. Which store type sells the maximum products by value and by quantity?

# %%
# Which store type sells the maximum products by value and by quantity?
ProductValue=Customer_Final.groupby('Store_type')[['Qty','total_amt']].agg({'Qty':'sum','total_amt':'sum'}).reset_index()

# %%
ProductValue.sort_values(['Qty','total_amt'],ascending=False)
# Out:
#        Store_type      Qty     total_amt
# 3          e-Shop  22763.0  1.982482e+07
# 1             MBR  11194.0  9.674486e+06
# 0  Flagship store  11133.0  9.715688e+06
# 2        TeleShop  10984.0  9.364781e+06

# %% [raw]
# Hence, Store Type e-shop sells maximun products by total amount(value) and by quantity

# %% [markdown]
# ### 8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
#What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores? 
StoreCategory=Customer_Final.loc[((Customer_Final.Store_type=='Flagship store') & ((Customer_Final.prod_cat == 'Electronics') | (Customer_Final.prod_cat == 'Clothing')))]

# %%
StoreCategory.head()
# Out:
#       customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 4095       274630 1970-02-01      M        4.0    7.853109e+10  274630.0
# 4100       270986 1970-03-27      M       10.0    1.435274e+10  270986.0
# 4101       270780 1970-04-18      F        3.0    5.397892e+10  270780.0
# 4106       271031 1970-06-09      F        2.0    6.829161e+10  271031.0
# 4107       273162 1970-06-19      M        8.0    6.886797e+10  273162.0
#
#       tran_date  prod_subcat_code  prod_cat_code  Qty    Rate      Tax  \
# 4095 2011-07-14               9.0            3.0  5.0   653.0  342.825
# 4100 2012-06-01               9.0            3.0  4.0   525.0  220.500
# 4101 2012-06-06               9.0            3.0  3.0   730.0  229.950
# 4106 2012-02-17               9.0            3.0  1.0   926.0   97.230
# 4107 2011-11-13               9.0            3.0  1.0  1411.0  148.155
#
#       total_amt      Store_type     prod_cat  prod_sub_cat_code prod_subcat
# 4095   3607.825  Flagship store  Electronics                  9     Cameras
# 4100   2320.500  Flagship store  Electronics                  9     Cameras
# 4101   2419.950  Flagship store  Electronics                  9     Cameras
# 4106   1023.230  Flagship store  Electronics                  9     Cameras
# 4107   1559.155  Flagship store  Electronics                  9     Cameras

# %%
StoreCategory.groupby('prod_cat').total_amt.sum()
# Out:
# prod_cat
# Clothing       1194423.23
# Electronics    2215136.04
# Name: total_amt, dtype: float64

# %% [raw]
# Hence, the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores are 2215136.04 and 1194423.23 rs respectively.

# %% [markdown]
# ### 9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
#What was the total amount earned from "Male" customers under the "Electronics" category? 
Electronic_Category_Male=Customer_Final.loc[((Customer_Final.prod_cat_code==3.0) & (Customer_Final.Gender == 'M'))]

# %%
Electronic_Category_Male.total_amt.sum()
# Out:
# 5703109.425

# %%
Electronic_Category_Male
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 4092        268408 1970-01-02      M        4.0    5.690286e+10  268408.0
# 4095        274630 1970-02-01      M        4.0    7.853109e+10  274630.0
# 4097        272359 1970-02-19      M        4.0    8.137937e+10  272359.0
# 4099        271692 1970-03-07      M        5.0    5.439176e+10  271692.0
# 4100        270986 1970-03-27      M       10.0    1.435274e+10  270986.0
# 4102        272555 1970-05-03      M        1.0    9.719974e+10  272555.0
# 4103        267386 1970-05-15      M        7.0    4.752384e+10  267386.0
# 4107        273162 1970-06-19      M        8.0    6.886797e+10  273162.0
# 4109        268447 1970-07-14      M        NaN    5.009313e+10  268447.0
# 4110        267042 1970-07-23      M        8.0    5.119765e+10  267042.0
# 4111        267280 1970-08-02      M        5.0    4.967053e+10  267280.0
# 4121        270619 1970-10-16      M        6.0    4.260985e+10  270619.0
# 4123        266972 1970-10-21      M        7.0    6.261747e+10  266972.0
# 4124        273929 1970-10-28      M        5.0    8.194235e+10  273929.0
# 4125        273122 1970-11-28      M        4.0    1.440455e+10  273122.0
# 4126        274486 1970-11-29      M        9.0    4.190440e+10  274486.0
# 4127        273664 1970-12-13      M        6.0    4.302443e+10  273664.0
# 4128        273664 1970-12-13      M        6.0    6.918559e+10  273664.0
# 4129        268636 1970-12-15      M        4.0    4.059262e+10  268636.0
# 4130        272126 1971-01-10      M        9.0    6.050999e+10  272126.0
# 4131        272126 1971-01-10      M        9.0    2.570632e+10  272126.0
# 4132        267558 1971-01-17      M        6.0    2.726343e+10  267558.0
# 22034 2012-09-23               5.0            3.0  1.0   538.0   56.490
# 22035 2012-09-08               5.0            3.0  3.0   910.0  286.650
# 22037 2013-04-12               5.0            3.0  2.0   615.0  129.150
# 22038 2013-08-16               5.0            3.0  3.0   969.0  305.235
# 22043 2014-01-26               5.0            3.0  1.0  1449.0  152.145
# 22046 2013-05-18               5.0            3.0  5.0  1095.0  574.875
#
#        total_amt      Store_type     prod_cat  prod_sub_cat_code prod_subcat
# 4092    4795.700          e-Shop  Electronics                  9     Cameras
# 4095    3607.825  Flagship store  Electronics                  9     Cameras
# 4097    1672.970          e-Shop  Electronics                  9     Cameras
# 4099    3205.605        TeleShop  Electronics                  9     Cameras
# 4100    2320.500  Flagship store  Electronics                  9     Cameras
# 4102    1907.230             MBR  Electronics                  9     Cameras
# 4103    4090.710          e-Shop  Electronics                  9     Cameras
# 4107    1559.155  Flagship store  Electronics                  9     Cameras
# 4109    4856.475        TeleShop  Electronics                  9     Cameras
# 4110     337.025          e-Shop  Electronics                  9     Cameras
# 4111    5342.675          e-Shop  Electronics                  9     Cameras
# 4121    1272.960          e-Shop  Electronics                  9     Cameras
# 4123    3043.170  Flagship store  Electronics                  9     Cameras
# 4124    4392.375          e-Shop  Electronics                  9     Cameras
# 4125    5113.940          e-Shop  Electronics                  9     Cameras
# 4126    4561.440          e-Shop  Electronics                  9     Cameras
# 4127    1845.350        TeleShop  Electronics                  9     Cameras
# 4128    4364.750          e-Shop  Electronics                  9     Cameras
# 4129     884.000          e-Shop  Electronics                  9     Cameras
# 4130    5381.350  Flagship store  Electronics                  9     Cameras
# 4131      81.770          e-Shop  Electronics                  9     Cameras
# 4132     533.715          e-Shop  Electronics                  9     Cameras
# 4133     196.690        TeleShop  Electronics                  9     Cameras
# 4134    7906.275  Flagship store  Electronics                  9     Cameras
# 4135    1955.850             MBR  Electronics                  9     Cameras
# 4136    1648.660             MBR  Electronics                  9     Cameras
# 4137    2348.125  Flagship store  Electronics                  9     Cameras
# 4138    2554.760          e-Shop  Electronics                  9     Cameras
# 4139    3549.260          e-Shop  Electronics                  9     Cameras
# 4140     870.740          e-Shop  Electronics                  9     Cameras
# ...          ...             ...          ...                ...         ...
# 21988   1057.485        TeleShop  Electronics                  5   Computers
# 21989  -3126.045             MBR  Electronics                  5   Computers
# 21990   3126.045             MBR  Electronics                  5   Computers
# 21991   2171.325          e-Shop  Electronics                  5   Computers
# 21992   3718.325             MBR  Electronics                  5   Computers
# 21993    906.100          e-Shop  Electronics                  5   Computers
# 21994    879.580          e-Shop  Electronics                  5   Computers
# 21996   1447.550        TeleShop  Electronics                  5   Computers
# 22004   2276.300          e-Shop  Electronics                  5   Computers
# 22005  -2326.025        TeleShop  Electronics                  5   Computers
# 22006   2326.025        TeleShop  Electronics                  5   Computers
# 22007   1021.020          e-Shop  Electronics                  5   Computers
# 22013    906.100          e-Shop  Electronics                  5   Computers
# 22014    842.010  Flagship store  Electronics                  5   Computers
# 22015    544.765          e-Shop  Electronics                  5   Computers
# 22018   6392.425             MBR  Electronics                  5   Computers
# 22019    596.700        TeleShop  Electronics                  5   Computers
# 22022     90.610          e-Shop  Electronics                  5   Computers
# 22023    712.725             MBR  Electronics                  5   Computers
# 22024   1267.435        TeleShop  Electronics                  5   Computers
# 22028   4689.620  Flagship store  Electronics                  5   Computers
# 22029    108.290          e-Shop  Electronics                  5   Computers
# 22030   3712.800          e-Shop  Electronics                  5   Computers
# 22033   -594.490          e-Shop  Electronics                  5   Computers
# 22034    594.490          e-Shop  Electronics                  5   Computers
# 22035   3016.650          e-Shop  Electronics                  5   Computers
# 22037   1359.150          e-Shop  Electronics                  5   Computers
# 22038   3212.235          e-Shop  Electronics                  5   Computers
# 22043   1601.145          e-Shop  Electronics                  5   Computers
# 22046   6049.875          e-Shop  Electronics                  5   Computers
#
# [2570 rows x 17 columns]

# %% [raw]
# Hence, the total amount earned from "Male" customers under the "Electronics" category is 5703109.425 rs

# %% [markdown]
# ### 10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
# How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts? 
positiveQuantityCustomers= Customer_Final.loc[(Customer_Final.Qty > 0)]

# %%
customerTransaction=positiveQuantityCustomers.groupby('customer_Id').transaction_id.count().reset_index()

# %%
customerTransaction.head()
# Out:
#    customer_Id  transaction_id
# 0       266783               4
# 1       266784               3
# 2       266785               7
# 3       266788               4
# 4       266794              11

# %%
customerTransaction.loc[customerTransaction.transaction_id > 10]
# Out:
#       customer_Id  transaction_id
# 4          266794              11
# 2426       270535              11
# 2606       270803              11
# 3867       272741              11
# 4032       273014              11
# 4815       274227              11

# %% [raw]
# The count of customers have more than 10 unique transactions, after removing all transactions which have any negative amounts is 6

# %% [markdown]
# ### 11. For all customers aged between 25 - 35, find out:

# %%
# For all customers aged between 25 - 35
Customer_Final['Age']=Customer_Final.DOB.apply(lambda x: int((datetime.now()-x).days/365))

# %%
AgeFilter=Customer_Final.loc[(Customer_Final.Age > 25)&(Customer_Final.Age < 35)]

# %% [markdown]
# #### a. What was the total amount spent for “Electronics” and “Books” product categories?

# %%
# What was the total amount spent for “Electronics” and “Books” product categories? 
CategoryAmount=AgeFilter.loc[(AgeFilter.prod_cat == 'Electronics') | (AgeFilter.prod_cat == 'Books')]

# %%
CategoryAmount.groupby('prod_cat').total_amt.sum()
# Out:
# prod_cat
# Books          4468196.785
# Electronics    3983213.390
# Name: total_amt, dtype: float64

# %% [raw]
# The total amount spent for individual "Electronic" and "Books" product categories are 4476887.61 and 3997611.54 respectively.

# %%
CategoryAmount.groupby('prod_cat').total_amt.sum().sum()
# Out:
# 8451410.175000008

# %% [raw]
# Hence, The total amount spent for "Electronic" and "Books" product categories is 8474499.15000001.

# %% [markdown]
# ####  b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
# What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?
AgeFilter.loc[(AgeFilter.tran_date > pd.to_datetime("2014-01-01")) & (AgeFilter.tran_date < pd.to_datetime("2014-03-01"))]
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id   cust_id  \
# 686         274991 1985-03-21      M        8.0    4.991692e+10  274991.0
# 20899 2014-01-20              12.0            6.0  1.0   939.0   98.595
# 20926 2014-02-06              12.0            6.0  2.0   571.0  119.910
# 20929 2014-01-19              12.0            6.0  5.0  1123.0  589.575
# 20967 2014-02-08              12.0            6.0  5.0   627.0  329.175
# 21034 2014-01-31              12.0            6.0  5.0  1476.0  774.900
# 21059 2014-01-05              12.0            6.0  3.0  1163.0  366.345
# 21089 2014-01-07              12.0            6.0  5.0   591.0  310.275
# 21743 2014-01-20               5.0            3.0  4.0   314.0  131.880
# 21747 2014-01-26               5.0            3.0  4.0   826.0  346.920
# 21872 2014-01-18               5.0            3.0  2.0  1365.0  286.650
# 21877 2014-02-03               5.0            3.0  4.0   859.0  360.780
# 21895 2014-01-20               5.0            3.0  1.0  1427.0  149.835
# 21904 2014-02-10               5.0            3.0  1.0   239.0   25.095
# 21948 2014-01-25               5.0            3.0  3.0   114.0   35.910
# 21965 2014-01-12               5.0            3.0  5.0   124.0   65.100
# 21998 2014-01-09               5.0            3.0  5.0   303.0  159.075
# 22015 2014-02-07               5.0            3.0  1.0   493.0   51.765
# 22043 2014-01-26               5.0            3.0  1.0  1449.0  152.145
# 22754 2014-02-11              10.0            5.0  4.0  1251.0  525.420
# 22828 2014-01-10              10.0            5.0  1.0   345.0   36.225
# 22895 2014-02-16              10.0            5.0  2.0   721.0  151.410
# 22912 2014-01-05              10.0            5.0  4.0  1121.0  470.820
# 22915 2014-02-08              10.0            5.0  3.0   298.0   93.870
# 22922 2014-01-14              10.0            5.0  1.0   778.0   81.690
# 22958 2014-01-09              10.0            5.0 -1.0 -1268.0  133.140
# 22959 2014-01-02              10.0            5.0  1.0  1268.0  133.140
# 22962 2014-01-03              10.0            5.0  1.0   583.0   61.215
#
#        total_amt      Store_type          prod_cat  prod_sub_cat_code  \
# 686     1747.005             MBR             Books                  7
# 724     5180.240  Flagship store             Books                  7
# 759     1303.900          e-Shop             Books                  7
# 804     2774.655          e-Shop             Books                  7
# 805     4486.300  Flagship store             Books                  7
# 849     2435.420  Flagship store             Books                  7
# 870     1580.150          e-Shop             Books                  7
# 889     6425.575             MBR             Books                  7
# 921     4232.150        TeleShop             Books                  7
# 951     2065.245             MBR             Books                  7
# 966     1161.355  Flagship store             Books                  7
# 986     8160.425             MBR             Books                  7
# 988      676.260          e-Shop             Books                  7
# 1011    1175.720          e-Shop             Books                  7
# 1018   -4745.975  Flagship store             Books                  7
# 1019    4745.975  Flagship store             Books                  7
# 1029    5060.900          e-Shop             Books                  7
# 1768    4994.600          e-Shop              Bags                  1
# 1770    6386.900             MBR              Bags                  1
# 1771   -1707.225        TeleShop              Bags                  1
# 1772    1707.225        TeleShop              Bags                  1
# 1780    2817.750          e-Shop              Bags                  1
# 1812    1867.450          e-Shop              Bags                  1
# 1828    2324.920             MBR              Bags                  1
# 1835    3391.245          e-Shop              Bags                  1
# 1860    2854.215  Flagship store              Bags                  1
# 1865    7768.150        TeleShop              Bags                  1
# 1870    1253.070          e-Shop              Bags                  1
# 1875     944.775             MBR              Bags                  1
# 1932    2900.625          e-Shop              Bags                  1
# ...          ...             ...               ...                ...
# 20838   1449.760  Flagship store  Home and kitchen                 12
# 20846   2254.200        TeleShop  Home and kitchen                 12
# 20891    434.265             MBR  Home and kitchen                 12
# 20899   1037.595             MBR  Home and kitchen                 12
# 20926   1261.910          e-Shop  Home and kitchen                 12
# 20929   6204.575  Flagship store  Home and kitchen                 12
# 20967   3464.175             MBR  Home and kitchen                 12
# 21034   8154.900             MBR  Home and kitchen                 12
# 21059   3855.345          e-Shop  Home and kitchen                 12
# 21089   3265.275          e-Shop  Home and kitchen                 12
# 21743   1387.880             MBR       Electronics                  5
# 21747   3650.920          e-Shop       Electronics                  5
# 21872   3016.650          e-Shop       Electronics                  5
# 21877   3796.780          e-Shop       Electronics                  5
# 21895   1576.835  Flagship store       Electronics                  5
# 21904    264.095             MBR       Electronics                  5
# 21948    377.910          e-Shop       Electronics                  5
# 21965    685.100        TeleShop       Electronics                  5
# 21998   1674.075             MBR       Electronics                  5
# 22015    544.765          e-Shop       Electronics                  5
# 22043   1601.145          e-Shop       Electronics                  5
# 22754   5529.420  Flagship store             Books                 10
# 22828    381.225        TeleShop             Books                 10
# 22895   1593.410          e-Shop             Books                 10
# 22912   4954.820        TeleShop             Books                 10
# 22915    987.870             MBR             Books                 10
# 22922    859.690             MBR             Books                 10
# 22958  -1401.140          e-Shop             Books                 10
# 22959   1401.140          e-Shop             Books                 10
# 22962    644.215          e-Shop             Books                 10
#
#        prod_subcat  Age
# 686        Fiction   34
# 724        Fiction   33
# 759        Fiction   33
# 804        Fiction   32
# 805        Fiction   32
# 849        Fiction   31
# 870        Fiction   30
# 889        Fiction   30
# 921        Fiction   29
# 951        Fiction   28
# 966        Fiction   28
# 986        Fiction   27
# 988        Fiction   27
# 1011       Fiction   27
# 1018       Fiction   27
# 1019       Fiction   27
# 1029       Fiction   27
# 1768          Mens   33
# 1770          Mens   33
# 1771          Mens   33
# 1772          Mens   33
# 1780          Mens   33
# 1812          Mens   32
# 1828          Mens   31
# 1835          Mens   31
# 1860          Mens   31
# 1865          Mens   31
# 1870          Mens   30
# 1875          Mens   30
# 1932          Mens   29
# ...            ...  ...
# 20838        Tools   32
# 20846        Tools   32
# 20891        Tools   31
# 20899        Tools   31
# 20926        Tools   30
# 20929        Tools   30
# 20967        Tools   29
# 21034        Tools   28
# 21059        Tools   27
# 21089        Tools   26
# 21743    Computers   33
# 21747    Computers   33
# 21872    Computers   30
# 21877    Computers   30
# 21895    Computers   30
# 21904    Computers   30
# 21948    Computers   29
# 21965    Computers   29
# 21998    Computers   28
# 22015    Computers   27
# 22043    Computers   26
# 22754  Non-Fiction   33
# 22828  Non-Fiction   32
# 22895  Non-Fiction   30
# 22912  Non-Fiction   30
# 22915  Non-Fiction   29
# 22922  Non-Fiction   29
# 22958  Non-Fiction   28
# 22959  Non-Fiction   28
# 22962  Non-Fiction   28
#
# [377 rows x 18 columns]

# %%
AgeFilter.loc[(AgeFilter.tran_date > pd.to_datetime("2014-01-01")) & (AgeFilter.tran_date < pd.to_datetime("2014-03-01"))].total_amt.sum()
# Out:
# 847915.1200000001
